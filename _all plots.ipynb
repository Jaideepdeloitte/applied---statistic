# %%
age_x=[25,26,27,29,33,32,35,28,35,39]
devop=[3525,3326,3627,3129,3633,3032,3115,3628,3435,3009]
javadop=[4525,5326,5627,5129,5633,5032,6115,6628,6435,6009]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(age_x,devop,label="All devep")
plt.plot(age_x,javadop,label="All Java ")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.legend()

# %%
age_x.sort()
devop.sort()
javadop.sort()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.plot(age_x,devop,label= 'all dev')
plt.plot(age_x,javadop,label = 'all java')
plt.xlabel('age')
plt.ylabel('salary')
plt.legend()

# %%
plt.plot(age_x,devop,label= 'all dev', linestyle= 'dotted')
plt.plot(age_x,javadop,label = 'all java', linestyle= 'dotted')
plt.xlabel('age')
plt.ylabel('salary')
plt.legend()

# %%
plt.plot(age_x,devop,label= 'all dev', linestyle= 'dotted')
plt.plot(age_x,javadop,label = 'all java', linestyle= 'dotted')
plt.xlabel('age')
plt.ylabel('salary')
plt.legend()
plt.grid()

# %%
plt.subplot(1, 2, 1)
plt.plot(age_x,devop,label= 'all dev', linestyle= 'dotted')
plt.xlabel('age')
plt.ylabel('salary')
plt.legend()

# %%
import numpy as np

# %%
plt.subplot(2, 1, 2)
plt.plot(age_x,javadop,label = 'all java', linestyle= 'dotted')

plt.xlabel('age')
plt.ylabel('salary')
plt.legend()

# %%
plt.scatter(age_x,javadop,label = 'all java', linestyle= 'dotted')
plt.show()

# %%
plt.scatter(age_x,devop,label= 'all dev', linestyle= 'dotted')
plt.show()

# %%
plt.bar(age_x,devop,label= 'all dev', linestyle= 'dotted')
plt.show()

# %%
plt.bar(age_x,javadop,label = 'all java', linestyle= 'dotted')
plt.show()
